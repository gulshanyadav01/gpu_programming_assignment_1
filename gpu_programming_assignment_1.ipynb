# %%
# !git clone https://github.com/gulshanyadav01/gpu_programming_assignment_1
# Out:
# Cloning into 'gpu_programming_assignment_1'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 16 (delta 1), reused 16 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (16/16), 24.26 KiB | 414.00 KiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd gpu_programming_assignment_1/
# Out:
# /content/gpu_programming_assignment_1

# %%
# %%bash
# nvcc -O3 -std=c++11 -arch=sm_75 \
#   -I./include \
#   -o pagerank \
#   src/main.cu src/graph.cu src/utils.cu src/kernels.cu

# %%
# !./pagerank
# Out:
# ...
#                 PageRank Algorithm - Complete CUDA Suite
# ...
#
# Using sample graph (7 nodes)...
# Graph Statistics:
#   Nodes: 7
#   Edges: 12
#   Average degree: 1.71
#   Max degree: 3
#
# ...
#                           BENCHMARKING RESULTS
# ...
#
# Configuration:
#   Iterations: 100
#   Damping factor: 0.85
#   Threads per block: 256
#
# Execution Times:
# --------------------------------------------------------------------------------
#   CPU Naive                      0.024 ms
#   CPU Optimized                  0.005 ms
#   GPU Naive                      1.124 ms
#   GPU Coalesced                  0.535 ms
#   GPU Shared Memory              0.569 ms
#   GPU Warp-Optimized             0.543 ms
#
# ...
#                           SPEEDUP ANALYSIS
# ...
#
# Speedup vs. CPU Naive:
# --------------------------------------------------------------------------------
#   CPU Optimized                   4.81x
#   GPU Naive                       0.02x
#   GPU Coalesced                   0.05x
# ...

# %%
# !./pagerank 1000   # 1,000 nodes
# !./pagerank 5000   # 5,000 nodes
# !./pagerank 10000  # 10,000 nodes
# Out:
# ...
#                 PageRank Algorithm - Complete CUDA Suite
# ...
#
# Generating random graph...
# Graph Statistics:
#   Nodes: 1000
#   Edges: 5000
#   Average degree: 5.00
#   Max degree: 5
#
# ...
#                           BENCHMARKING RESULTS
# ...
#
# Configuration:
#   Iterations: 100
#   Damping factor: 0.85
#   Threads per block: 256
#
# Execution Times:
# --------------------------------------------------------------------------------
#   CPU Naive                    398.238 ms
#   CPU Optimized                  0.960 ms
#   GPU Naive                    113.968 ms
#   GPU Coalesced                  1.083 ms
#   GPU Shared Memory              1.392 ms
#   GPU Warp-Optimized             1.080 ms
#
# ...
#                           SPEEDUP ANALYSIS
# ...
#
# Speedup vs. CPU Naive:
# --------------------------------------------------------------------------------
#   CPU Optimized                 414.78x
#   GPU Naive                       3.49x
#   GPU Coalesced                 367.60x
# ...
